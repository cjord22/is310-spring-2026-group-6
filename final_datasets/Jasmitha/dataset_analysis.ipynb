# %%
state_counts = df["state"].value_counts()

print(state_counts.head(20))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 state_counts = df["state"].value_counts()
#       2
#       3 print(state_counts.head(20))
#
# NameError: name 'df' is not defined
